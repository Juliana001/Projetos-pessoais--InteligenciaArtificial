# %% [markdown]
# <a href="https://colab.research.google.com/github/Juliana001/Projetos-pessoais---Data-Science-e-Machine-Learning/blob/main/Projetos%20Machine%20Learning/Criando_voz_com_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install playsound

# %%
# !pip install gTTS

# %%
# !pip install googletrans==4.0.0-rc1

# %%
import gtts
from google.colab import drive
from IPython.display import Audio
from googletrans import Translator

# %%
from playsound import playsound
# Out:
# WARNING:playsound:playsound is relying on another python subprocess. Please use `pip install pygobject` if you want playsound to run more efficiently.

# %%
with open('/content/drive/MyDrive/Projeto fala python/projeto fala python.txt', 'w') as arquivo:
    # Escrever no arquivo
    arquivo.write("The concept of time travel has always fascinated humanity. From H.G. Wells' 'The Time Machine' to modern scientific theories, the idea of traversing through time has captured our imagination. What if we could visit the past or glimpse into the future? How would it impact our lives and the course of history? Time travel remains one of the most intriguing and debated topics, fueling countless stories, movies, and scientific inquiries.\n")

# %%
# Função para traduzir o conteúdo de um arquivo
def traduzir_arquivo(caminho_arquivo, idioma_destino='en'):
    translator = Translator()

    # Abrir o arquivo para leitura
    with open(caminho_arquivo, 'r', encoding='utf-8') as arquivo:
        conteudo = arquivo.read()

    # Traduzir o conteúdo para o idioma de destino
    traducao = translator.translate(conteudo, dest=idioma_destino)

    # Retornar o texto traduzido
    return traducao.text

# Caminho do arquivo original
caminho_arquivo_original = '/content/drive/MyDrive/Projeto fala python/projeto fala python.txt'

# Traduzindo o conteúdo do arquivo para inglês
conteudo_traduzido = traduzir_arquivo(caminho_arquivo_original, idioma_destino='pt')

# Salvando a tradução como um arquivo MP3
frase = gtts.gTTS(text=conteudo_traduzido, lang='pt')
frase.save('/content/frase_traduzida.mp3')

# Reproduzindo o arquivo de áudio da tradução
Audio('/content/frase_traduzida.mp3', autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
